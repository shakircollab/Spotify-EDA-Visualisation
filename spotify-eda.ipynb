# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spotify-top-100-songs-of-20152019/Spotify 2010 - 2019 Top 100.csv
# /kaggle/input/spotify-top-100-songs-of-20152019/Spotify 2010 - 2019 Top 100 Songs.xlsx

# %%
# Read the dataset
main_df = pd.read_csv("/kaggle/input/spotify-top-100-songs-of-20152019/Spotify 2010 - 2019 Top 100.csv")
df = main_df.copy()
df
# Out:
#                                               title            artist  \
# 0                     STARSTRUKK (feat. Katy Perry)             3OH!3
# 1                       My First Kiss (feat. Ke$ha)             3OH!3
# 2                                   I Need A Dollar        Aloe Blacc
# 3     Airplanes (feat. Hayley Williams of Paramore)             B.o.B
# 4                 Nothin' on You (feat. Bruno Mars)             B.o.B
# ...                                             ...               ...
# 998                     Strike a Pose (feat. Aitch)  Young T & Bugsey
# 999       The London (feat. J. Cole & Travis Scott)        Young Thug
# 1000                                            NaN               NaN
# 1001                                            NaN               NaN
# 1002                                            NaN               NaN
#
#         top genre  year released       added    bpm  nrgy  dnce   dB  live  \
# 0       dance pop         2009.0  2022‑02‑17  140.0  81.0  61.0 -6.0  23.0
# 1       dance pop         2010.0  2022‑02‑17  138.0  89.0  68.0 -4.0  36.0
# 2        pop soul         2010.0  2022‑02‑17   95.0  48.0  84.0 -7.0   9.0
# 3     atl hip hop         2010.0  2022‑02‑17   93.0  87.0  66.0 -4.0   4.0
# 4     atl hip hop         2010.0  2022‑02‑17  104.0  85.0  69.0 -6.0   9.0
# ...           ...            ...         ...    ...   ...   ...  ...   ...
# 998     afroswing         2019.0  2020‑08‑20  138.0  58.0  53.0 -6.0  10.0
# 999   atl hip hop         2019.0  2020‑06‑22   98.0  59.0  80.0 -7.0  13.0
# 1000          NaN            NaN         NaN    NaN   NaN   NaN  NaN   NaN
# 1001          NaN            NaN         NaN    NaN   NaN   NaN  NaN   NaN
# 1002          NaN            NaN         NaN    NaN   NaN   NaN  NaN   NaN
#
#        val    dur  acous  spch   pop  top year artist type
# 0     23.0  203.0    0.0   6.0  70.0    2010.0         Duo
# 1     83.0  192.0    1.0   8.0  68.0    2010.0         Duo
# 2     96.0  243.0   20.0   3.0  72.0    2010.0        Solo
# 3     38.0  180.0   11.0  12.0  80.0    2010.0        Solo
# 4     74.0  268.0   39.0   5.0  79.0    2010.0        Solo
# ...    ...    ...    ...   ...   ...       ...         ...
# 998   59.0  214.0    1.0  10.0  67.0    2019.0         Duo
# 999   18.0  200.0    2.0  15.0  75.0    2019.0        Solo
# 1000   NaN    NaN    NaN   NaN   NaN       NaN         NaN
# 1001   NaN    NaN    NaN   NaN   NaN       NaN         NaN
# 1002   NaN    NaN    NaN   NaN   NaN       NaN         NaN
#
# [1003 rows x 17 columns]

# %%
# Imports
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Shape
df.shape
# Out:
# (1003, 17)

# %%
# Missing values in the dataset
df.isnull().sum()
# Out:
# title            3
# artist           3
# top genre        3
# year released    3
# added            3
# bpm              3
# nrgy             3
# dnce             3
# dB               3
# live             3
# val              3
# dur              3
# acous            3
# spch             3
# pop              3
# top year         3
# artist type      3
# dtype: int64

# %%
# Delete last three rows
df = df.iloc[:-3 , :]

# %%
# Missing values in the dataset, should be 0
df.isnull().sum()
# Out:
# title            0
# artist           0
# top genre        0
# year released    0
# added            0
# bpm              0
# nrgy             0
# dnce             0
# dB               0
# live             0
# val              0
# dur              0
# acous            0
# spch             0
# pop              0
# top year         0
# artist type      0
# dtype: int64

# %%
# Check for duplicates
titleUnique = len(set(df.title))
titlesTotal = df.shape[0]
titlesdupe = titlesTotal - titleUnique
print(titlesdupe)
# No need to drop as soome artists have mulitple hits
#train.drop(['Id'],axis =1,inplace=True)
# Out:
# 55

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1000 non-null   object
#  1   artist         1000 non-null   object
#  2   top genre      1000 non-null   object
#  3   year released  1000 non-null   float64
#  4   added          1000 non-null   object
#  5   bpm            1000 non-null   float64
#  6   nrgy           1000 non-null   float64
#  7   dnce           1000 non-null   float64
#  8   dB             1000 non-null   float64
#  9   live           1000 non-null   float64
#  10  val            1000 non-null   float64
#  11  dur            1000 non-null   float64
#  12  acous          1000 non-null   float64
#  13  spch           1000 non-null   float64
#  14  pop            1000 non-null   float64
#  15  top year       1000 non-null   float64
#  16  artist type    1000 non-null   object
# dtypes: float64(12), object(5)
# memory usage: 132.9+ KB

# %%
df.describe()
# Out:
#        year released          bpm         nrgy         dnce           dB  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     2014.390000   121.262000    69.502000    66.876000    -5.663000
# std         3.241359    26.238022    15.961415    13.121921     2.025224
# min      1975.000000    65.000000     6.000000    19.000000   -18.000000
# 25%      2012.000000   100.000000    59.000000    59.000000    -7.000000
# 50%      2014.000000   122.000000    71.000000    68.000000    -5.000000
# 75%      2017.000000   134.000000    81.250000    75.000000    -4.000000
# max      2021.000000   206.000000    98.000000    96.000000    -1.000000
#
#               live          val          dur       acous         spch  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     17.911000    50.901000   220.406000    14.36900    10.064000
# std      13.431511    21.563399    39.927677    19.45403     9.276743
# min       2.000000     4.000000   113.000000     0.00000     2.000000
# 25%       9.000000    35.000000   197.000000     2.00000     4.000000
# 50%      12.000000    50.500000   216.000000     6.00000     6.000000
# 75%      23.000000    68.000000   237.000000    19.00000    12.000000
# max      83.000000    97.000000   688.000000    98.00000    53.000000
#
#                pop     top year
# count  1000.000000  1000.000000
# mean     74.840000  2014.500000
# std       8.807836     2.873719
# min      35.000000  2010.000000
# 25%      70.000000  2012.000000
# 50%      76.000000  2014.500000
# 75%      81.000000  2017.000000
# max      95.000000  2019.000000

# %%
df.corr()
# Out:
#                year released       bpm      nrgy      dnce        dB  \
# year released       1.000000 -0.017916 -0.237744  0.222459 -0.116566
# bpm                -0.017916  1.000000  0.118557 -0.111660  0.089568
# nrgy               -0.237744  0.118557  1.000000 -0.129279  0.713428
# dnce                0.222459 -0.111660 -0.129279  1.000000 -0.040538
# dB                 -0.116566  0.089568  0.713428 -0.040538  1.000000
# live               -0.115106  0.014672  0.184094 -0.113324  0.128134
# val                -0.091306  0.021128  0.372866  0.264781  0.317128
# dur                -0.248134 -0.016536 -0.049662 -0.168483 -0.082541
# acous               0.151539 -0.124614 -0.504083 -0.075999 -0.392393
# spch                0.149373  0.149368 -0.099790  0.161734 -0.165838
# pop                 0.182793 -0.025058 -0.234011  0.093176 -0.145403
# top year            0.854339 -0.016887 -0.302535  0.218019 -0.173286
#
#                    live       val       dur     acous      spch       pop  \
# year released -0.115106 -0.091306 -0.248134  0.151539  0.149373  0.182793
# bpm            0.014672  0.021128 -0.016536 -0.124614  0.149368 -0.025058
# nrgy           0.184094  0.372866 -0.049662 -0.504083 -0.099790 -0.234011
# dnce          -0.113324  0.264781 -0.168483 -0.075999  0.161734  0.093176
# dB             0.128134  0.317128 -0.082541 -0.392393 -0.165838 -0.145403
# live           1.000000  0.028092 -0.003094 -0.116081  0.043516 -0.137305
# val            0.028092  1.000000 -0.185863 -0.164048  0.013192 -0.003752
# dur           -0.003094 -0.185863  1.000000  0.026474 -0.035451  0.009219
# acous         -0.116081 -0.164048  0.026474  1.000000 -0.010204  0.128195
# spch           0.043516  0.013192 -0.035451 -0.010204  1.000000  0.061441
# pop           -0.137305 -0.003752  0.009219  0.128195  0.061441  1.000000
# top year      -0.121331 -0.122825 -0.215213  0.181747  0.165890  0.268054
#
#                top year
# year released  0.854339
# bpm           -0.016887
# nrgy          -0.302535
# dnce           0.218019
# dB            -0.173286
# live          -0.121331
# val           -0.122825
# dur           -0.215213
# acous          0.181747
# spch           0.165890
# pop            0.268054
# top year       1.000000

# %%
df['year released'] = df['year released'].astype('Int64')
df['top year'] = df['top year'].astype('Int64')

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['top year'])
# Out:
# <AxesSubplot:xlabel='top year'>

# %%
df.groupby('top genre')['top genre'].count().sort_values(ascending=False)
# Out:
# top genre
# dance pop        361
# pop               57
# atl hip hop       39
# art pop           37
# hip hop           21
#                 ...
# idol               1
# indie folk         1
# dark clubbing      1
# basshall           1
# acoustic pop       1
# Name: top genre, Length: 132, dtype: int64

# %%
px.scatter(df, x='year released',y='top year', color=df['artist'])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6efe5034-4e2c-45cc-8fcd-bc880fa71511" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6efe5034-4e2c-45cc-8fcd-bc880fa71511")) {                    Plotly.newPlot(                        "6efe5034-4e2c-45cc-8fcd-bc880fa71511",                        [{"hovertemplate":"artist=3OH!3<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"3OH!3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"3OH!3","orientation":"v","showlegend":true,"x":[2009,2010],"xaxis":"x","y":[2010,2010],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Aloe Blacc<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"Aloe Blacc","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Aloe Blacc","orientation":"v","showlegend":true,"x":[2010,2014],"xaxis":"x","y":[2010,2014],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=B.o.B<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"B.o.B","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"B.o.B","orientation":"v","showlegend":true,"x":[2010,2010,2010,2012],"xaxis":"x","y":[2010,2010,2010,2012],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Black Eyed Peas<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"Black Eyed Peas","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Black Eyed Peas","orientation":"v","showlegend":true,"x":[2010,2009,2010],"xaxis":"x","y":[2010,2010,2011],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Bruno Mars<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"Bruno Mars","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Bruno Mars","orientation":"v","showlegend":true,"x":[2010,2010,2010,2010,2010,2012,2011,2012,2012,2012,2016,2016,2017],"xaxis":"x","y":[2010,2010,2011,2011,2011,2012,2012,2013,2013,2013,2017,2017,2018],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Cali Swag District<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"Cali Swag District","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Cali Swag District","orientation":"v","showlegend":true,"x":[2011],"xaxis":"x","y":[2010],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=CeeLo Green<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"CeeLo Green","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"CeeLo Green","orientation":"v","showlegend":true,"x":[2010],"xaxis":"x","y":[2010],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Chris Brown<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"Chris Brown","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Chris Brown","orientation":"v","showlegend":true,"x":[2011,2011,2011,2019,2012,2014,2014,2014,2015,2015],"xaxis":"x","y":[2010,2011,2011,2011,2012,2013,2014,2014,2015,2016],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=David Guetta<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"David Guetta","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"David Guetta","orientation":"v","showlegend":true,"x":[2009,2009,2011,2010,2011,2011,2014,2014,2016],"xaxis":"x","y":[2010,2010,2011,2011,2012,2013,2014,2014,2016],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=DJ Khaled<br>year released=%{x}<br>top year=%{y}<extra></extra>","legendgroup":"DJ Khaled","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"DJ Khaled","orientation":"v","showlegend":true,"x":[2010,2011,2017,2017,2018],"xaxis":"x","y":[2010,2011,2017,2017,2018],"yaxis":"y","type":"scatter"},{"hovertemplate":"artist=Drake< ...

# %%
px.density_heatmap(df, y="top year", x="artist", nbinsx=20, nbinsy=20)
# Out:
# <div>                            <div id="d810f663-090f-4195-8d8b-e703e090e100" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d810f663-090f-4195-8d8b-e703e090e100")) {                    Plotly.newPlot(                        "d810f663-090f-4195-8d8b-e703e090e100",                        [{"coloraxis":"coloraxis","hovertemplate":"artist=%{x}<br>top year=%{y}<br>count=%{z}<extra></extra>","name":"","nbinsx":20,"nbinsy":20,"x":["3OH!3","3OH!3","Aloe Blacc","B.o.B","B.o.B","B.o.B","Black Eyed Peas","Black Eyed Peas","Bruno Mars","Bruno Mars","Cali Swag District","CeeLo Green","Chris Brown","David Guetta","David Guetta","DJ Khaled","Drake","Drake","Duck Sauce","Edward Maya","Eliza Doolittle","Ellie Goulding","Eminem","Eminem","Enrique Iglesias","Example","Far East Movement","Flo Rida","INNA","Iyaz","Jason Derulo","Jason Derulo","Jason Derulo","Jay Sean","Jay Sean","JAY-Z","John Mayer","John Mayer","Justin Bieber","Katy Perry","Katy Perry","Kelly Rowland","Kesha","Kesha","Kesha","Kesha","K'NAAN","Kris Allen","Lady Gaga","Lady Gaga","Lady Gaga","Lil Wayne","Ludacris","Ludacris","Maroon 5","Matt Cardle","Mike Posner","Miley Cyrus","Neon Trees","Owl City","Plan B","Rihanna","Rihanna","Rihanna","Rihanna","Rihanna","Robyn","Sara Bareilles","Scouting For Girls","Sean Kingston","Sidney Samson","Stromae","Sugarland","Swedish House Mafia","Swedish House Mafia","Taio Cruz","Taio Cruz","Take That","Taylor Swift","Taylor Swift","Taylor Swift","The Band Perry","The Script","The Wanted","Tim Berg","Timbaland","Timbaland","Tinie Tempah","Tinie Tempah","Train","Travie McCoy","Trey Songz","Trey Songz","Two Door Cinema Club","Usher","Usher","Usher","Waka Flocka Flame","Yolanda Be Cool","Young Money","Adele","Adele","Alexandra Stan","Avril Lavigne","Bad Meets Evil","Beyoncé","Beyoncé","Birdy","Black Eyed Peas","Blake Shelton","Bon Iver","Britney Spears","Britney Spears","Bruno Mars","Bruno Mars","Bruno Mars","Calvin Harris","Chase & Status","Chip","Chris Brown","Chris Brown","Chris Brown","Christina Perri","Cobra Starship","Coldplay","Coldplay","David Guetta","David Guetta","Diddy - Dirty Money","DJ Fresh","DJ Khaled","Dr. Dre","Drake","Ed Sheeran","Ed Sheeran","Edward Maya","Enrique Iglesias","Eric Church","Example","Far East Movement","Florence + The Machine","Foster The People","Grouplove","Gym Class Heroes","Hot Chelle Rae","Jason Aldean","Jason Derulo","Jason Derulo","Jennifer Lopez","Jeremih","Jessie J","Kanye West","Katy Perry","Katy Perry","Katy Perry","Kelly Rowland","Keri Hilson","Kesha","Kesha","Labrinth","Lady A","Lady Gaga","Lady Gaga","Lil Wayne","Lil Wayne","LMFAO","LMFAO","Lupe Fiasco","Lykke Li","M83","Mac Miller","Mann","Maroon 5","Miguel","Nickelback","Nicki Minaj","Noah And The Whale","Olly Murs","OneRepublic","P!nk","Pitbull","Pitbull","Professor Green","Red Hot Chili Peppers","Rihanna","Rihanna","Rihanna","Rizzle Kicks","Sak Noel","Selena Gomez & The Scene","Selena Gomez & The Scene","Snoop Dogg","Swedish House Mafia","Taio Cruz","The Band Perry","The Wanted","Usher","Waka Flocka Flame","Wiz Khalifa","Wiz Khalifa","Adele","Adele","Alesso","Alex Clare","alt-J","Arctic Monkeys","Asaf Avidan","Avicii","Avicii","Azealia Banks","B.o.B","Bruno Mars","Bruno Mars","Calvin Harris","Calvin Harris","Calvin Harris","Carly Rae Jepsen","Carrie Underwood","Cher Lloyd","Chris Brown","Coldplay","Coldplay","David Guetta","DEV","Disclosure","DJ Fresh","Drake","Drake","Ellie Goulding","Flo Rida","Florence + The Machine","Frank Ocean","Frank Ocean","fun.","fun.","Gotye","Grimes","Gym Class Heroes","Icona Pop","Imagine Dragons","Imagine Dragons","JAY-Z","Justin Bieber","Kanye West","Karmin","Katy Perry","Katy Perry","Kendrick Lamar","Kendrick Lamar","Kesha","Kesha","Lana Del Rey","Lana Del Rey","Lana Del Rey","Lin ...

# %%
idsUnique = len(set(df.title))
idsTotal = df.shape[0]
idsdupe = idsTotal - idsUnique
print(idsdupe)
# Out:
# 55
